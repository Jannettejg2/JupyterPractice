# %% [markdown]
# <a href="https://colab.research.google.com/github/Jannettejg2/JupyterPractice/blob/main/Dispersi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Base de costos xlsx

# %%
import pandas as pd
archivo_excel = pd.read_excel('20210410.xlsx')
print(archivo_excel.columns)
# Out:
# Index(['Unnamed: 0', 'FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO',
#        'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE', 'PROVEEDOR', 'MUNICIPIO',
#        'ENTIDAD', 'DESTINO', 'DELMUN', 'COORDENADAS ORIGEN',
#        'COORDENADAS DESTINO', 'COSTO REAL', 'COSTO OBJETIVO', 'ID CASO',
#        'TIPO POLIZA RETAIL'],
#       dtype='object')

# %%
df_short = df[['FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE', 'PROVEEDOR', 'MUNICIPIO',  'ENTIDAD', 'DESTINO', 'DELMUN', 'COORDENADAS ORIGEN', 'COORDENADAS DESTINO', 'COSTO REAL', 'COSTO OBJETIVO', 'ID CASO',  'TIPO POLIZA RETAIL']]

# %%
df_short
# Out:
#        FECHA_DATOS                 CAMPANA  ...    ID CASO TIPO POLIZA RETAIL
# 0      31-ene-2021               URGE GRUA  ...        NaN              OTROS
# 1      31-ene-2021                  COPPEL  ...        NaN             RETAIL
# 2      31-ene-2021                GNP VIAL  ...        NaN        ASEGURADORA
# 3      31-ene-2021                  COPPEL  ...        NaN             RETAIL
# 4      31-ene-2021                  COPPEL  ...        NaN             RETAIL
# ...            ...                     ...  ...        ...                ...
# 60637  31-mar-2021  TOTAL CARE EMPRESARIAL  ...  1537140.0              OTROS
# 60638  31-mar-2021  TOTAL CARE EMPRESARIAL  ...  1537140.0              OTROS
# 60639  31-mar-2021  IDENTIDAD SEGURA INVEX  ...  1537142.0              OTROS
# 60640  31-mar-2021  INVEX PROTECCION TOTAL  ...  1537143.0              OTROS
# 60641  30-abr-2021     CONTACTO MEDICO ORO  ...  1537146.0              OTROS
#
# [60642 rows x 18 columns]

# %%
writer = pd.ExcelWriter('20210410_Costos.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Base de costos CSV

# %%
import pandas as pd
df = pd.read_csv("ReporteTotal.csv", sep=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    FECHA_DATOS    CAMPANA  ...              GNP VIAL - NOMBRE GNP VIAL - POLIZA
# 0  31-ene-2021  URGE GRUA  ...                            NaN               NaN
# 1  31-ene-2021     COPPEL  ...                            NaN               NaN
# 2  31-ene-2021   GNP VIAL  ...  FEDERICO MANUEL PINEDO BERROS         421620659
# 3  31-ene-2021     COPPEL  ...                            NaN               NaN
# 4  31-ene-2021     COPPEL  ...                            NaN               NaN
#
# [5 rows x 62 columns]

# %%
df.columns
# Out:
# Index(['FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO', 'TIPO DE VEHICULO',
#        'ENVIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE',
#        'DÍA DE FECHA DEL SERVICIO', 'KMS', 'PROVEEDOR', 'MUNICIPIO', 'ENTIDAD',
#        'DELMUN', 'DESTINO', 'RUTA 2', 'COSTO REAL', 'COSTO CLIENTE',
#        'COSTO TOTAL', 'PROMEDIO 2020', 'COSTO MAXIMO 2020',
#        'COSTO MINIMO 2020', 'COSTO CONVENIO', 'CONVENIO CORRECTO',
#        'COSTO KILOMETRO', 'KMS NÚMERO', 'FACTOR DE COBRO', 'NO COTIZACIONES',
#        'COSTO L1', 'COSTO L2', 'COSTO L3', 'COSTO F', 'COSTO NOCTURNO',
#        'COSTO TARIFA', 'ENTIDAD ORIGEN GRUA', 'COSTO COTIZACION',
#        'COSTO AUTORIZADO', 'ES AUTORIZADO', 'USUARIO AUTORIZA',
#        'KILOMETROS ORIGEN GRUA - ENGANCHE',
#        'KILOMETROS ENGANCHE - DESTINO USUARIO', 'COORDENADAS ORIGEN',
#        'COORDENADAS DESTINO', 'EJECUTIVO GENERA SRVICIO',
#        'EJECUTIVO CIERRA SERVICIO', 'ULTIMO ESTATUS SERVICIO',
# ...

# %%
df_short = df[['FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE', 'PROVEEDOR', 'MUNICIPIO',  'ENTIDAD', 'DESTINO', 'DELMUN', 'COORDENADAS ORIGEN', 'COORDENADAS DESTINO', 'COSTO REAL', 'COSTO OBJETIVO', 'ID CASO',  'TIPO POLIZA RETAIL']]

# %%
df_short
# Out:
#        FECHA_DATOS                 CAMPANA  ...    ID CASO TIPO POLIZA RETAIL
# 0      31-ene-2021               URGE GRUA  ...        NaN              OTROS
# 1      31-ene-2021                  COPPEL  ...        NaN             RETAIL
# 2      31-ene-2021                GNP VIAL  ...        NaN        ASEGURADORA
# 3      31-ene-2021                  COPPEL  ...        NaN             RETAIL
# 4      31-ene-2021                  COPPEL  ...        NaN             RETAIL
# ...            ...                     ...  ...        ...                ...
# 60637  31-mar-2021  TOTAL CARE EMPRESARIAL  ...  1537140.0              OTROS
# 60638  31-mar-2021  TOTAL CARE EMPRESARIAL  ...  1537140.0              OTROS
# 60639  31-mar-2021  IDENTIDAD SEGURA INVEX  ...  1537142.0              OTROS
# 60640  31-mar-2021  INVEX PROTECCION TOTAL  ...  1537143.0              OTROS
# 60641  30-abr-2021     CONTACTO MEDICO ORO  ...  1537146.0              OTROS
#
# [60642 rows x 18 columns]

# %%
writer = pd.ExcelWriter('2021.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Base de Redes

# %% [markdown]
# ###Hogar

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_hogar.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Persona_1 Casa_3 Nextel (Radio)_5
# 0          512            NaN        No  ...          0      0                0
# 1        16323            NaN        No  ...          0      0                0
# 2        16323            NaN        No  ...          0      0                0
# 3        16323            NaN        No  ...          0      0                0
# 4        16323            NaN        No  ...          0      0                0
#
# [5 rows x 98 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Celular_1',
#        'Correo Electrónico_1', 'Correo Electrónico_2', 'EntidadSucursal',
#        'MunicipioSucursal', 'Latitud', 'Longitud', 'Direccion', 'CodigoPostal',
#        'Negocio_1', 'PrioridadSucursal', 'CostoL1', 'CostoL2', 'Oficina_1',
#        'Oficina_2', 'Fax_1', 'Lada sin costo_1', 'Lada sin costo_2',
#        'Oficina_3', 'CostoL1Muerto', 'CostoF', 'CostoKMRecorrido',
#        'CostoKMUsuario', 'FactorCobro', 'Negocio_2', 'Consultorio_1',
#        'Nextel (Radio)_1', 'Negocio_3', 'Celular_2', 'Casa_1', 'Celular_3',
# ...

# %%
df_short = df[['IdProveedor', 'IdProveedorT5','IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoL2Muerto', 'CostoF',
       'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoN', 'PrvActivo', 'SucActiva', 'Latitud', 'Longitud']]

# %%
df_short
# Out:
#       IdProveedor  IdProveedorT5  IdSucursal  ...  SucActiva    Latitud    Longitud
# 0             512            NaN         400  ...          1  18.503611  -88.305278
# 1           16323            NaN       26652  ...          1  19.374444  -99.284722
# 2           16323            NaN       26653  ...          1   0.000000    0.000000
# 3           16323            NaN       26654  ...          1   0.000000    0.000000
# 4           16323            NaN       26655  ...          1   0.000000    0.000000
# ...           ...            ...         ...  ...        ...        ...         ...
# 6204        16139        29345.0       20874  ...          1  20.284444 -103.425278
# 6205        16419        30035.0       22372  ...          1  17.067778  -96.720000
# 6206          218        66666.0         236  ...          1  19.406667  -99.191111
# 6207          508        17348.0         355  ...          1  19.406667  -99.191111
# ...

# %%
writer = pd.ExcelWriter('Hogar.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Mascotas

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_veterinarios.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Oficina_4 CostoL3 Casa_1
# 0        11037            NaN        No  ...          0       0      0
# 1        12145            NaN        No  ...          0       0      0
# 2        12357            NaN        No  ...          0       0      0
# 3        15767        26749.0        No  ...          0       0      0
# 4        15772        26755.0        No  ...          0       0      0
#
# [5 rows x 57 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Oficina_1',
#        'EntidadSucursal', 'MunicipioSucursal', 'Latitud', 'Longitud',
#        'Direccion', 'CodigoPostal', 'PrioridadSucursal', 'CostoF',
#        'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoFMuerto',
#        'Correo Electrónico_1', 'Negocio_1', 'CostoL1', 'CostoL1Muerto',
#        'Consultorio_1', 'Celular_1', 'CostoL2', 'Consultorio_2', 'Celular_2',
#        'Correo Electrónico_2', 'Correo Corporativo_1', 'Persona_1',
#        'Oficina_2', 'Oficina_3', 'Negocio_2', 'Oficina_4', 'CostoL3',
#        'Casa_1'],
#       dtype='object')

# %%
df_short = df[['IdProveedor', 'IdProveedorT5', 'IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio', 'CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoF', 'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro','PrvActivo', 'SucActiva', 'Latitud', 'Longitud']]

# %%
df_short
# Out:
#       IdProveedor  IdProveedorT5  IdSucursal  ...  SucActiva    Latitud    Longitud
# 0           11037            NaN       11304  ...          1  32.534722 -117.043611
# 1           12145            NaN       12505  ...          0  32.663333 -115.467778
# 2           12357            NaN       12731  ...          1  32.663333 -115.467778
# 3           15767        26749.0       19510  ...          0  21.880833 -102.296111
# 4           15772        26755.0       19515  ...          0  28.593889 -105.887778
# ...           ...            ...         ...  ...        ...        ...         ...
# 5236        19076        30693.0       26253  ...          1  22.771667 -102.575278
# 5237        20159            NaN       29373  ...          1  19.845833  -90.536667
# 5238        20165            NaN       29378  ...          1  18.614722  -99.180278
# 5239        16019        28262.0       19771  ...          1  19.538056  -96.909167
# ...

# %%
writer = pd.ExcelWriter('Mascotas.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Medicos

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_medtangible.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Lada sin costo_2 Oficina_3 Persona_1
# 0        20116        31732.0        No  ...                 0         0         0
# 1        20261            NaN        No  ...                 0         0         0
# 2        16118        29260.0        No  ...                 0         0         0
# 3        16118        29260.0        No  ...                 0         0         0
# 4        16118        29260.0        No  ...                 0         0         0
#
# [5 rows x 56 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Celular_1', 'Celular_2',
#        'EntidadSucursal', 'MunicipioSucursal', 'Latitud', 'Longitud',
#        'Direccion', 'CodigoPostal', 'Oficina_1', 'Negocio_1', 'Consultorio_1',
#        'Consultorio_2', 'Localizador_1', 'Negocio_2', 'Celular_3',
#        'Correo Electrónico_1', 'Correo Electrónico_2', 'Correo Electrónico_3',
#        'Oficina_2', 'PrioridadSucursal', 'CostoL1', 'CostoL2', 'CostoL2Muerto',
#        'CostoL1Muerto', 'Casa_1', 'Fax_1', 'Lada sin costo_1',
#        'Lada sin costo_2', 'Oficina_3', 'Persona_1'],
#       dtype='object')

# %%
df_short = df[['IdProveedor', 'IdProveedorT5','IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoL2Muerto','PrvActivo', 'SucActiva', 'Latitud', 'Longitud']]

# %%
df_short
# Out:
#      IdProveedor  IdProveedorT5  IdSucursal  ...  SucActiva    Latitud    Longitud
# 0          20116        31732.0       27924  ...          1  19.361111  -99.350833
# 1          20261            NaN       29508  ...          1  20.676389 -103.342222
# 2          16118        29260.0       19871  ...          0  19.045278  -98.197500
# 3          16118        29260.0       19872  ...          1  20.588056 -100.388056
# 4          16118        29260.0       19873  ...          1  25.671389 -100.308611
# ..           ...            ...         ...  ...        ...        ...         ...
# 298        19692        31667.0       29305  ...          1  19.609722  -99.060000
# 299        19692        31667.0       29306  ...          1  19.400000  -99.200000
# 300        19692        31667.0       29315  ...          1  19.443056  -99.144444
# 301        19692        31667.0       29316  ...          1  19.482222  -99.112500
# ...

# %%
writer = pd.ExcelWriter('Medico.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Grúa

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_vial.csv", sep=";")

# %%
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Oficina_9 Celular_10 Consultorio_6
# 0           82           82.0        Si  ...          0          0             0
# 1           93           85.0        No  ...          0          0             0
# 2           93           85.0        No  ...          0          0             0
# 3           92         8702.0        No  ...          0          0             0
# 4           92         8702.0        No  ...          0          0             0
#
# [5 rows x 96 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Oficina_1', 'Oficina_2',
#        'Celular_1', 'Nextel (Radio)_1', 'Correo Electrónico_1',
#        'EntidadSucursal', 'MunicipioSucursal', 'Latitud', 'Longitud',
#        'Direccion', 'CodigoPostal', 'PrioridadSucursal', 'CostoL1', 'CostoF',
#        'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoL1Muerto',
#        'Celular_2', 'Celular_3', 'CostoL2', 'CostoL2Muerto', 'CostoL3',
#        'CostoL3Muerto', 'Oficina_3', 'Negocio_1', 'Negocio_2', 'Celular_4',
#        'Oficina_4', 'Correo Electrónico_2', 'Negocio_3', 'Negocio_4', 'Fax_1',
# ...

# %%
df_short = df[['IdProveedor', 'IdProveedorT5','IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoL2Muerto', 'CostoF',
       'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoN', 'PrvActivo', 'SucActiva', 'Latitud', 'Longitud']]

# %%
df_short
# Out:
#       IdProveedor  IdProveedorT5  IdSucursal  ...  SucActiva    Latitud    Longitud
# 0              82           82.0          87  ...          1  20.817500 -102.757222
# 1              93           85.0          98  ...          0  20.293333 -103.189722
# 2              93           85.0         290  ...          0  20.284444 -103.425278
# 3              92         8702.0          97  ...          0  19.105556  -96.107778
# 4              92         8702.0         426  ...          0  19.190278  -96.153333
# ...           ...            ...         ...  ...        ...        ...         ...
# 2142          520        21295.0       26087  ...          1  19.645000  -99.169444
# 2143          520        21295.0       29516  ...          1  19.716111  -99.223611
# 2144        20276        31788.0       29521  ...          1  19.358333  -99.093056
# 2145        20277            NaN       29522  ...          1  19.374444  -99.284722
# ...

# %%
writer = pd.ExcelWriter('Grúa.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Auxilio Vial

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_auxilio_vial.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Oficina_8 Localizador_1 Localizador_2
# 0           44        20798.0        No  ...          0             0             0
# 1           44        20798.0        No  ...          0             0             0
# 2           44        20798.0        No  ...          0             0             0
# 3           44        20798.0        No  ...          0             0             0
# 4           82           82.0        Si  ...          0             0             0
#
# [5 rows x 97 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Negocio_1', 'Negocio_2',
#        'Negocio_3', 'Celular_1', 'Correo Electrónico_1', 'Negocio_4',
#        'Negocio_5', 'Negocio_6', 'Negocio_7', 'Celular_2', 'Oficina_1',
#        'EntidadSucursal', 'MunicipioSucursal', 'Latitud', 'Longitud',
#        'Direccion', 'CodigoPostal', 'PrioridadSucursal', 'CostoL1',
#        'CostoL1Muerto', 'Oficina_2', 'Nextel (Radio)_1', 'CostoF',
#        'CostoKMRecorrido', 'Celular_3', 'FactorCobro', 'Oficina_3', 'CostoL2',
#        'Celular_4', 'Oficina_4', 'CostoKMUsuario', 'Correo Electrónico_2',
# ...

# %%
df_short = df[['IdProveedor', 'IdProveedorT5','IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoL2Muerto', 'CostoF',
       'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoN', 'PrvActivo', 'SucActiva', 'Latitud', 'Longitud']]

# %%
writer = pd.ExcelWriter('Aux_Vial.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# # Base Operaciones

# %%
import pandas as pd
df = pd.read_csv("reporteGeneral.csv", sep=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (17,18,19,20,26,42,44,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#        PERIODO  ID CASO  ...  NOMBRE AJUSTADOR HDI               USUARIO ASIGNA
# 0  31-ene-2020        0  ...                   NaN                          NaN
# 1  31-ene-2020        0  ...                   NaN       DIEGO PABELLO MARTINEZ
# 2  31-ene-2020        0  ...                   NaN                          NaN
# 3  31-ene-2020        0  ...                   NaN  OSVALDO JAVIER REYES VALDEZ
# 4  31-ene-2020        0  ...                   NaN          AGUSTIN TREJO BRAVO
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['PERIODO', 'ID CASO', 'ID SERVICIO', 'SISTEMA', 'CLIENTE CORPORATIVO',
#        'CODIGO CAMPAÑA', 'CAMPAÑA', 'TIPO POLIZA', 'SERVICIO', 'TANGIBLE',
#        'ENVIO', 'ESTATUS', 'COSTO CLIENTE', 'COSTO CORPORATIVO',
#        'COSTO TELASIST', 'COSTO TOTAL', 'FECHA REPORTE', 'FECHA ASIGNACION',
#        'FECHA ARRIBO', 'FECHA CONTACTO', 'FECHA TERMINO', 'TIEMPO ASIGNACION',
#        'TIEMPO ARRIBO', 'COTIZACIONES', 'BANDERA ASIGNACION', 'BANDERA ARRIBO',
#        'KMS APROXIMADOS', 'KMS SERVICIO', 'KMS PROV FORANEO', 'KMS TOTALES',
#        'COSTO BANDERAZO', 'COSTO KM', 'DIA REPORTE', 'PROVEEDOR',
#        'ENTIDAD ORIGEN', 'MUNICIPIO ORIGEN', 'ENTIDAD DESTINO',
#        'MUNICIPIO DESTINO', 'RUTA', 'AGENTE APERTURA', 'COSTO OBJETIVO',
#        'ADICIONALES', 'TIPIFICACION FIN', 'ID AJUSTADOR HDI',
#        'NOMBRE AJUSTADOR HDI', 'USUARIO ASIGNA'],
#       dtype='object')

# %%
df_short = df[['PERIODO', 'ID CASO', 'ID SERVICIO', 'CAMPAÑA','SERVICIO', 'ENVIO', 'ESTATUS', 'COSTO TELASIST', 'FECHA REPORTE', 'TIEMPO ARRIBO', 'BANDERA ARRIBO', 'PROVEEDOR',
       'ENTIDAD ORIGEN', 'MUNICIPIO ORIGEN', 'ENTIDAD DESTINO',
       'MUNICIPIO DESTINO']]

# %%
df_short
# Out:
#             PERIODO  ID CASO  ...   ENTIDAD DESTINO MUNICIPIO DESTINO
# 0       31-ene-2020        0  ...           HIDALGO       DESCONOCIDO
# 1       31-ene-2020        0  ...           HIDALGO   PACHUCA DE SOTO
# 2       31-ene-2020        0  ...            SONORA       DESCONOCIDO
# 3       31-ene-2020        0  ...        TAMAULIPAS         MATAMOROS
# 4       31-ene-2020        0  ...            SONORA            CAJEME
# ...             ...      ...  ...               ...               ...
# 248665  31-dic-2020  1535243  ...            MEXICO       DESCONOCIDO
# 248666  31-dic-2020  1537350  ...           JALISCO       DESCONOCIDO
# 248667  31-dic-2020  1537351  ...  CIUDAD DE MEXICO       DESCONOCIDO
# 248668  31-ene-2021  1537354  ...   BAJA CALIFORNIA       DESCONOCIDO
# 248669  31-ene-2021  1537356  ...  CIUDAD DE MEXICO       DESCONOCIDO
#
# [248670 rows x 16 columns]

# %%
writer = pd.ExcelWriter('Tiempos.xlsx')
df_short.to_excel(writer)
writer.save()
