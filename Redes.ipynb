# %% [markdown]
# <a href="https://colab.research.google.com/github/Jannettejg2/JupyterPractice/blob/main/Redes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Archivo Costos

# %%
import pandas as pd
df = pd.read_csv("AGEEML_2021121221882.csv", sep=",")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-7bdcb6d9cea6> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("AGEEML_2021121221882.csv", sep=",")
#       3 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b666bf274d0a> in <module>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df_short = df[['FECHA_DATOS', 'CAMPAÑA', 'ID_SERVICIO', 'SERVICIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE',
'PROVEEDOR', 'MUNICIPIO', 'ENTIDAD', 'DELMUN', 'DESTINO', 'COSTO REAL', 'COSTO OBJETIVO', 'ID CASO', 'TIPO POLIZA RETAIL']]

# %%
df_short

# %%
writer = pd.ExcelWriter('2018.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# #### Calculadora

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_vial.csv", sep=";")

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
df.tail()

# %%
df.columns

# %%
df.dtypes

# %%
df['IdProveedor']

# %%
df_short = df[['IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoL2Muerto', 'CostoF',
       'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoN', 'PrvActivo', 'SucActiva','IdProveedor', 'IdProveedorT5']]

# %%
df_short

# %%
writer = pd.ExcelWriter('proveedor.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ####Referencias

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_referencias.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Lada sin costo_2 Oficina_3 Persona_1
# 0        20116        31732.0        No  ...                 0         0         0
# 1        16118        29260.0        No  ...                 0         0         0
# 2        16118        29260.0        No  ...                 0         0         0
# 3        16118        29260.0        No  ...                 0         0         0
# 4        16118        29260.0        No  ...                 0         0         0
#
# [5 rows x 69 columns]

# %%
df_short = df[['IdProveedor', 'IdProveedorT5', 'IdSucursal', 'Prioridad', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio', 'especialidad_1', 'PrvActivo', 'SucActiva']]

# %%
writer = pd.ExcelWriter('Med_Tab.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ####Hogar

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_hogar.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Persona_1 Casa_3 Nextel (Radio)_5
# 0          512            NaN        No  ...          0      0                0
# 1        16323            NaN        No  ...          0      0                0
# 2        16323            NaN        No  ...          0      0                0
# 3        16323            NaN        No  ...          0      0                0
# 4        16323            NaN        No  ...          0      0                0
#
# [5 rows x 97 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Celular_1',
#        'Correo Electrónico_1', 'Correo Electrónico_2', 'EntidadSucursal',
#        'MunicipioSucursal', 'Latitud', 'Longitud', 'Direccion', 'CodigoPostal',
#        'Negocio_1', 'PrioridadSucursal', 'CostoL1', 'CostoL2', 'Oficina_1',
#        'Oficina_2', 'Fax_1', 'Lada sin costo_1', 'Lada sin costo_2',
#        'Oficina_3', 'CostoL1Muerto', 'CostoF', 'CostoKMRecorrido',
#        'CostoKMUsuario', 'FactorCobro', 'Negocio_2', 'Consultorio_1',
#        'Nextel (Radio)_1', 'Negocio_3', 'Celular_2', 'Casa_1', 'Celular_3',
# ...

# %%
df_short = df[['IdProveedor', 'IdProveedorT5','IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoL2Muerto', 'CostoF',
       'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoN', 'PrvActivo', 'SucActiva']]

# %%
df_short
# Out:
#       IdProveedor  IdProveedorT5  IdSucursal  ...  CostoN  PrvActivo SucActiva
# 0             512            NaN         400  ...       0         Si         1
# 1           16323            NaN       26652  ...       0         Si         1
# 2           16323            NaN       26653  ...       0         Si         1
# 3           16323            NaN       26654  ...       0         Si         1
# 4           16323            NaN       26655  ...       0         Si         1
# ...           ...            ...         ...  ...     ...        ...       ...
# 6198        16139        29345.0       20874  ...       0         Si         1
# 6199        16419        30035.0       22372  ...       0         Si         1
# 6200          218        66666.0         236  ...       0         Si         1
# 6201          508        17348.0         355  ...       0         Si         1
# 6202        18795            NaN       25821  ...       0         Si         1
#
# ...

# %%
writer = pd.ExcelWriter('Hogar.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ####Médico

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_medtangible.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Casa_2 Fax_1 Lada sin costo_2
# 0           39        21465.0        No  ...       0     0                0
# 1           39        21465.0        No  ...       0     0                0
# 2           39        21465.0        No  ...       0     0                0
# 3           39        21465.0        No  ...       0     0                0
# 4           39        21465.0        No  ...       0     0                0
#
# [5 rows x 80 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'EntidadSucursal',
#        'MunicipioSucursal', 'Latitud', 'Longitud', 'Direccion', 'CodigoPostal',
#        'PrioridadSucursal', 'CostoL1', 'CostoL1Muerto', 'Oficina_1',
#        'Celular_1', 'Celular_2', 'Correo Electrónico_1', 'Celular_3',
#        'Celular_4', 'CostoF', 'CostoKMRecorrido', 'FactorCobro',
#        'Nextel (Radio)_1', 'Nextel (Radio)_2', 'Negocio_1', 'CostoL2',
#        'CostoL2Muerto', 'Celular_5', 'Negocio_2', 'Negocio_3', 'Negocio_4',
#        'CostoKMUsuario', 'CostoFMuerto', 'Persona_1', 'Oficina_2',
# ...

# %%
df_short = df[['IdProveedor', 'IdProveedorT5','IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoL2Muerto','PrvActivo', 'SucActiva']]

# %%
df_short
# Out:
#       IdProveedor  IdProveedorT5  ...  PrvActivo  SucActiva
# 0              39        21465.0  ...         Si          0
# 1              39        21465.0  ...         Si          1
# 2              39        21465.0  ...         Si          0
# 3              39        21465.0  ...         Si          1
# 4              39        21465.0  ...         Si          1
# ...           ...            ...  ...        ...        ...
# 4890          508        17348.0  ...         Si          1
# 4891        16296        29705.0  ...         Si          0
# 4892        16296        29705.0  ...         Si          1
# 4893        19335        30727.0  ...         No          1
# 4894        20116        31732.0  ...         Si          1
#
# [4895 rows x 16 columns]

# %%
writer = pd.ExcelWriter('Medico.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ####Mascotas

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_veterinarios.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5 EnAsistco  ...  Oficina_4 CostoL3 Casa_1
# 0        11037            NaN        No  ...          0       0      0
# 1        12145            NaN        No  ...          0       0      0
# 2        12357            NaN        No  ...          0       0      0
# 3        15767        26749.0        No  ...          0       0      0
# 4        15772        26755.0        No  ...          0       0      0
#
# [5 rows x 57 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Oficina_1',
#        'EntidadSucursal', 'MunicipioSucursal', 'Latitud', 'Longitud',
#        'Direccion', 'CodigoPostal', 'PrioridadSucursal', 'CostoF',
#        'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoFMuerto',
#        'Correo Electrónico_1', 'Negocio_1', 'CostoL1', 'CostoL1Muerto',
#        'Consultorio_1', 'Celular_1', 'CostoL2', 'Consultorio_2', 'Celular_2',
#        'Correo Electrónico_2', 'Correo Corporativo_1', 'Persona_1',
#        'Oficina_2', 'Oficina_3', 'Negocio_2', 'Oficina_4', 'CostoL3',
#        'Casa_1'],
#       dtype='object')

# %%
df_short = df[['IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio', 'CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoF', 'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro','PrvActivo', 'SucActiva','IdProveedor', 'IdProveedorT5']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8bdd34e87da8> in <module>()
# ----> 1 df_short = df[['IdSucursal', 'Prioridad', 'PrioridadSucursal', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio', 'CostoL1', 'CostoL1Muerto', 'CostoL2', 'CostoF', 'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro','PrvActivo', 'SucActiva','IdProveedor', 'IdProveedorT5']]
#
# NameError: name 'df' is not defined

# %%
df_short
# Out:
#       IdProveedor  IdProveedorT5  IdSucursal  ...  FactorCobro  PrvActivo SucActiva
# 0           11037            NaN       11304  ...          1.0         No         1
# 1           12145            NaN       12505  ...          1.0         No         0
# 2           12357            NaN       12731  ...          1.0         No         1
# 3           15767        26749.0       19510  ...          0.0         No         0
# 4           15772        26755.0       19515  ...          0.0         No         0
# ...           ...            ...         ...  ...          ...        ...       ...
# 5235        19076        30693.0       26253  ...          0.0         Si         1
# 5236        20159            NaN       29373  ...          0.0         Si         1
# 5237        20165            NaN       29378  ...          0.0         Si         1
# 5238        16019        28262.0       19771  ...          0.0         Si         1
# ...

# %%
writer = pd.ExcelWriter('Mascotas.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ####TABLERO

# %%
import pandas as pd
df = pd.read_csv("20200106_Reporte_Total.csv", sep=",")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-804f79b4e4e9> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("20200106_Reporte_Total.csv", sep=",")
#       3 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
print ()
df.shape
# Out:
# (199293, 59)

# %%
print ()
df.count
# Out:
# <bound method DataFrame.count of         FECHA_DATOS           CAMPANA  ...  ORDEN COMPRA   FECHA ORDEN COMPRA
# 0       31-ene-2020            COPPEL  ...           NaN                  NaN
# 1       31-ene-2020            COPPEL  ...           NaN                  NaN
# 2       31-ene-2020       REPORTE BX+  ...           NaN                  NaN
# 3       31-ene-2020            COPPEL  ...       70429.0  2020-01-02 08:37:47
# 4       31-ene-2020            COPPEL  ...           NaN                  NaN
# ...             ...               ...  ...           ...                  ...
# 199288  31-ene-2021            COPPEL  ...           NaN                  NaN
# 199289  31-ene-2021            COPPEL  ...           NaN                  NaN
# 199290  31-ene-2021  VIDA BANAMEX MAS  ...           NaN                  NaN
# 199291  31-ene-2021            COPPEL  ...           NaN                  NaN
# 199292  31-ene-2021            COPPEL  ...           NaN                  NaN
#
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
pd.crosstab(df.CAMPANA, df.ENVIO, margins=True, margins_name="Total")
# Out:
# ENVIO                                              FORÁNEO  LOCAL   Total
# CAMPANA
# A MEDICA FAMILIAR                                       14     18      32
# ACCIDENTES PERSONALES EXPRESS                          300      0     300
# AI SMART HOUSE                                           0    135     135
# AMBULANCIA CHUBB_CONSULTORES E INTEGRADORES DE IT        4      0       4
# AON ASSIST                                               2      8      10
# ...                                                    ...    ...     ...
# VALLY ASISTENCIA INTEGRAL                                2      0       2
# VIAJES PREMIER                                           2      0       2
# VIDA BANAMEX MAS                                      5657   8837   14494
# VIDA FACIL                                             518     13     531
# Total                                               117676  81617  199293
#
# [83 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO', 'TIPO DE VEHICULO',
#        'ENVIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE',
#        'DÍA DE FECHA DEL SERVICIO', 'KMS', 'PROVEEDOR', 'MUNICIPIO', 'ENTIDAD',
#        'DELMUN', 'DESTINO', 'RUTA 2', 'COSTO REAL', 'COSTO CLIENTE',
#        'COSTO TOTAL', 'PROMEDIO 2020', 'COSTO MAXIMO 2020',
#        'COSTO MINIMO 2020', 'COSTO CONVENIO', 'CONVENIO CORRECTO',
#        'COSTO KILOMETRO', 'KMS NÚMERO', 'FACTOR DE COBRO', 'NO COTIZACIONES',
#        'COSTO L1', 'COSTO L2', 'COSTO L3', 'COSTO F', 'COSTO NOCTURNO',
#        'COSTO TARIFA', 'ENTIDAD ORIGEN GRUA', 'COSTO COTIZACION',
#        'COSTO AUTORIZADO', 'ES AUTORIZADO', 'USUARIO AUTORIZA',
#        'KILOMETROS ORIGEN GRUA - ENGANCHE',
#        'KILOMETROS ENGANCHE - DESTINO USUARIO', 'COORDENADAS ORIGEN',
#        'COORDENADAS DESTINO', 'EJECUTIVO GENERA SRVICIO',
#        'EJECUTIVO CIERRA SERVICIO', 'ULTIMO ESTATUS SERVICIO',
# ...

# %%
df_short = df[['FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO', 'TIPO DE VEHICULO', 'ENVIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE', 'KMS', 'PROVEEDOR', 'MUNICIPIO', 'ENTIDAD',
       'DELMUN', 'DESTINO', 'COSTO REAL','COORDENADAS ORIGEN', 'COORDENADAS DESTINO','TIPO COSTO', 'PROVEEDOR PRIORIDAD', 'TIPO POLIZA RETAIL', 'ENTIDAD ORIGEN GRUA']]

# %%
df_short
# Out:
#         FECHA_DATOS  ...         ENTIDAD ORIGEN GRUA
# 0       31-ene-2020  ...  SIN ENTIDAD ORIGEN DE GRUA
# 1       31-ene-2020  ...  SIN ENTIDAD ORIGEN DE GRUA
# 2       31-ene-2020  ...  SIN ENTIDAD ORIGEN DE GRUA
# 3       31-ene-2020  ...                    VERACRUZ
# 4       31-ene-2020  ...  SIN ENTIDAD ORIGEN DE GRUA
# ...             ...  ...                         ...
# 199288  31-ene-2021  ...  SIN ENTIDAD ORIGEN DE GRUA
# 199289  31-ene-2021  ...                    VERACRUZ
# 199290  31-ene-2021  ...  SIN ENTIDAD ORIGEN DE GRUA
# 199291  31-ene-2021  ...  SIN ENTIDAD ORIGEN DE GRUA
# 199292  31-ene-2021  ...             PUERTO VALLARTA
#
# [199293 rows x 22 columns]

# %%
writer = pd.ExcelWriter('Tablero2020.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ####Laboratorio

# %%
import pandas as pd
df = pd.read_csv("redes_proveedores_laboratorios.csv", sep=";")
df.head()
# Out:
#    IdProveedor  IdProveedorT5  ... EstudioLab_57_Costo_TLM  Celular_2
# 0        13147        20126.0  ...                       0          0
# 1        13147        20126.0  ...                       0          0
# 2        13147        20126.0  ...                       0          0
# 3        13148        22042.0  ...                       0          0
# 4        13150        21833.0  ...                       0          0
#
# [5 rows x 204 columns]

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo',
#        ...
#        'EstudioLab_53_Costo_TLM', 'EstudioLab_54_Tipo',
#        'EstudioLab_54_Costo_TLM', 'EstudioLab_55_Tipo',
#        'EstudioLab_55_Costo_TLM', 'EstudioLab_56_Tipo',
#        'EstudioLab_56_Costo_TLM', 'EstudioLab_57_Tipo',
#        'EstudioLab_57_Costo_TLM', 'Celular_2'],
#       dtype='object', length=204)

# %%
df_short = df[['IdProveedor', 'IdProveedorT5', 'IdSucursal', 'Prioridad', 'NombreComercial', 'EntidadSucursal', 'MunicipioSucursal', 'NombreSucursal', 'TipoServicio','PrvActivo', 'SucActiva', 'Direccion', 'CodigoPostal']]

# %%
writer = pd.ExcelWriter('Laboratorios.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Objetivos

# %%
import pandas as pd
df = pd.read_csv("reporteGeneral.csv", sep=",")
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (26,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        PERIODO  ...                      USUARIO ASIGNA
# 0  31-ene-2020  ...  MARIA DEL CARMEN MARTINEZ GONZALEZ
# 1  31-ene-2020  ...      CHRISTIAN JOSUE ZEPEDA SANCHEZ
# 2  31-ene-2020  ...              JOSE LUIS OSORIO LOPEZ
# 3  31-ene-2020  ...           ROSSA FRANCIA PINTOS DIAZ
# 4  31-ene-2020  ...        MARTHA LAURA VILCHIS CAMACHO
#
# [5 rows x 46 columns]

# %%
print ()
df.shape
# Out:
# (274298, 46)

# %%
df.columns
# Out:
# Index(['PERIODO', 'ID CASO', 'ID SERVICIO', 'SISTEMA', 'CLIENTE CORPORATIVO',
#        'CODIGO CAMPAÑA', 'CAMPAÑA', 'TIPO POLIZA', 'SERVICIO', 'TANGIBLE',
#        'ENVIO', 'ESTATUS', 'COSTO CLIENTE', 'COSTO CORPORATIVO',
#        'COSTO TELASIST', 'COSTO TOTAL', 'FECHA REPORTE', 'FECHA ASIGNACION',
#        'FECHA ARRIBO', 'FECHA CONTACTO', 'FECHA TERMINO', 'TIEMPO ASIGNACION',
#        'TIEMPO ARRIBO', 'COTIZACIONES', 'BANDERA ASIGNACION', 'BANDERA ARRIBO',
#        'KMS APROXIMADOS', 'KMS SERVICIO', 'KMS PROV FORANEO', 'KMS TOTALES',
#        'COSTO BANDERAZO', 'COSTO KM', 'DIA REPORTE', 'PROVEEDOR',
#        'ENTIDAD ORIGEN', 'MUNICIPIO ORIGEN', 'ENTIDAD DESTINO',
#        'MUNICIPIO DESTINO', 'RUTA', 'AGENTE APERTURA', 'COSTO OBJETIVO',
#        'ADICIONALES', 'TIPIFICACION FIN', 'ID AJUSTADOR HDI',
#        'NOMBRE AJUSTADOR HDI', 'USUARIO ASIGNA'],
#       dtype='object')

# %%
df_short = df[['PERIODO', 'CAMPAÑA', 'ID SERVICIO', 'SERVICIO', 'ENVIO', 'ESTATUS', 'FECHA REPORTE', 'PROVEEDOR', 'MUNICIPIO ORIGEN', 'ENTIDAD ORIGEN', 'ENTIDAD DESTINO',
       'MUNICIPIO DESTINO', 'COSTO TELASIST', 'COSTO OBJETIVO', 'ID CASO', 'TIPO POLIZA']]

# %%
df_short
# Out:
#             PERIODO                 CAMPAÑA  ...  ID CASO  TIPO POLIZA
# 0       31-ene-2020                  COPPEL  ...        0       RETAIL
# 1       31-ene-2020                  COPPEL  ...        0       RETAIL
# 2       31-ene-2020         MULTIASISTENCIA  ...        0        OTROS
# 3       31-ene-2020                BX+ VIAL  ...        0  ASEGURADORA
# 4       31-ene-2020             REPORTE BX+  ...        0        OTROS
# ...             ...                     ...  ...      ...          ...
# 274293  31-dic-2020          SEGUROS AZTECA  ...  1535243        OTROS
# 274294  31-dic-2020               TELEMEDIC  ...  1537350        OTROS
# 274295  31-dic-2020     CONTACTO MEDICO ORO  ...  1537351        OTROS
# 274296  31-ene-2021  INVEX PROTECCION TOTAL  ...  1537354        OTROS
# 274297  31-ene-2021     CONTACTO MEDICO ORO  ...  1537356        OTROS
#
# [274298 rows x 16 columns]

# %%
writer = pd.ExcelWriter('Objetivos.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Rutas y disperción

# %%
import pandas as pd
df = pd.read_csv("20200106_Reporte_Total.csv", sep=",")
df.head()

# %%
df_short
writer = pd.ExcelWriter('Tablero2019.xlsx')
df_short.to_excel(writer)
writer.save()

# %% [markdown]
# ###Archivo de costos 2019

# %%
import pandas as pd
archivo_excel = pd.read_excel('20200706_Reporte_Total_TMONE_y_T5_2019.xlsx')
print(archivo_excel.columns)

# %%
df_short = archivo_excel[['FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE',
       'DÍA DE FECHA DEL SERVICIO', 'PROVEEDOR', 'MUNICIPIO', 'ENTIDAD', 'COSTO OBJETIVO', 'ID CASO',
       'DELMUN', 'DESTINO', 'COSTO REAL', 'GNP TIPO POLIZA]]

# %%
import pandas as pd
df = pd.read_csv("20200106_Reporte_Total.csv", sep=",")
df.head()

# %%
df.columns

# %%
df_short = df[['FECHA_DATOS', 'CAMPANA', 'ID_SERVICIO', 'SERVICIO', 'ENVIO (ESPECIFICO)', 'ESTATUS', 'REPORTE', 'PROVEEDOR', 'MUNICIPIO', 'ENTIDAD',
       'DELMUN', 'DESTINO', 'COSTO REAL', 'COSTO OBJETIVO', 'ID CASO','TIPO POLIZA RETAIL']]

# %%
df_short

# %%
writer = pd.ExcelWriter('costos.xlsx')
df_short.to_excel(writer)
writer.save()

# %%
import pandas as pd
df = pd.read_csv("AGEEML_2021121221882.csv", sep=",")
df.head()

# %% [markdown]
# ####Archivos rar

# %%
# <= Click this cell to rar the folder

# !apt-get install rar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   rar
# 0 upgraded, 1 newly installed, 0 to remove and 29 not upgraded.
# Need to get 295 kB of archives.
# After this operation, 799 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 rar amd64 2:5.5.0-1 [295 kB]
# Fetched 295 kB in 2s (170 kB/s)
# Selecting previously unselected package rar.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../rar_2%3a5.5.0-1_amd64.deb ...
# Unpacking rar (2:5.5.0-1) ...
# Setting up rar (2:5.5.0-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !rar a "ReporteProveedoresCorreoFacturacion"
# Out:
# RAR 5.50   Copyright (c) 1993-2017 Alexander Roshal   11 Aug 2017
# Trial version             Type 'rar -?' for help
#
# Evaluation copy. Please register.
#
# Updating archive ReporteProveedoresCorreoFacturacion.rar
#
# WARNING: No files

# %% [markdown]
# ###Objetivos / Estatus Terminado

# %%
import pandas as pd
df = pd.read_csv("reporteGeneral.csv", sep=",")
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (18,19,26,42,44,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        PERIODO  ...                         USUARIO ASIGNA
# 0  31-ene-2020  ...  CESAR DANIEL ARMANDO CARRILLO ARTEAGA
# 1  31-ene-2020  ...                                    NaN
# 2  31-ene-2020  ...                    AGUSTIN TREJO BRAVO
# 3  31-ene-2020  ...                   DIEGO HERNANDEZ CRUZ
# 4  31-ene-2020  ...            OSVALDO JAVIER REYES VALDEZ
#
# [5 rows x 46 columns]

# %%
print ()
df.shape
# Out:
# (2167, 96)

# %%
df.columns
# Out:
# Index(['IdProveedor', 'IdProveedorT5', 'EnAsistco', 'Prioridad',
#        'NombreComercial', 'TipoServicio', 'FechaAlta', 'UsuarioAlta',
#        'UltimaModificacion', 'PrvActivo', 'FueraRed', 'Bloqueo', 'PagoDirecto',
#        'PagoUrgente', 'IdSrvTipo', 'IdBanco', 'Banco', 'SucursalBanco',
#        'BancoCuenta', 'BancoClabe', 'TarjetaHabiente', 'RFC', 'Curp',
#        'IdSucursal', 'NombreSucursal', 'SucActiva', 'Oficina_1', 'Oficina_2',
#        'Celular_1', 'Nextel (Radio)_1', 'Correo Electrónico_1',
#        'EntidadSucursal', 'MunicipioSucursal', 'Latitud', 'Longitud',
#        'Direccion', 'CodigoPostal', 'PrioridadSucursal', 'CostoL1', 'CostoF',
#        'CostoKMRecorrido', 'CostoKMUsuario', 'FactorCobro', 'CostoL1Muerto',
#        'Celular_2', 'Celular_3', 'CostoL2', 'CostoL2Muerto', 'CostoL3',
#        'CostoL3Muerto', 'Oficina_3', 'Negocio_1', 'Negocio_2', 'Celular_4',
#        'Oficina_4', 'Correo Electrónico_2', 'Negocio_3', 'Negocio_4', 'Fax_1',
# ...

# %%
df_short = df[['PERIODO', 'CAMPAÑA', 'ID SERVICIO', 'SERVICIO', 'ENVIO', 'ESTATUS', 'FECHA REPORTE', 'PROVEEDOR', 'MUNICIPIO ORIGEN', 'ENTIDAD ORIGEN', 'ENTIDAD DESTINO',
       'MUNICIPIO DESTINO', 'COSTO TELASIST', 'COSTO OBJETIVO', 'ID CASO', 'TIPO POLIZA']]

# %%
df_short
# Out:
#             PERIODO                 CAMPAÑA  ...  ID CASO  TIPO POLIZA
# 0       31-ene-2020                GNP VIAL  ...        0  ASEGURADORA
# 1       31-ene-2020                  COPPEL  ...        0       RETAIL
# 2       31-ene-2020   CASA SEGURA SANTANDER  ...        0        OTROS
# 3       31-ene-2020         MULTIASISTENCIA  ...        0        OTROS
# 4       31-ene-2020                  COPPEL  ...        0       RETAIL
# ...             ...                     ...  ...      ...          ...
# 265093  30-jun-2020  INVEX PROTECCION TOTAL  ...  1535238        OTROS
# 265094  30-jun-2020  INVEX PROTECCION TOTAL  ...  1535238        OTROS
# 265095  30-jun-2020  INVEX PROTECCION TOTAL  ...  1535238        OTROS
# 265096  30-jun-2020               TELEMEDIC  ...  1535239        OTROS
# 265097  30-jun-2020      CARE VOLARIS INVEX  ...  1535240  ASEGURADORA
#
# [265098 rows x 16 columns]

# %%
df_mask=df['col_name']=='specific_value'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-09ef34a1356f> in <module>()
# ...

# %%
writer = pd.ExcelWriter('Objetivos.xlsx')
df_short.to_excel(writer)
writer.save()
