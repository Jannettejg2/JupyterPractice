# %%
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
cdmx = pd.read_csv('servicios-de-atencion-a-violencia-contra-las-mujeres.csv')

# %%
cdmx.iloc[0:5]
# Out:
#    id id_ente  id_sede                     nombre_de_la_sede  \
# 0   0     FGJ  FGJ-005  Coordinacion Territorial Az-1 y Az-3
# 1   1     FGJ  FGJ-007  Coordinación Territorial BJ-3 y Bj-4
# 2   2     FGJ  FGJ-010        Coordinación Territorial Coy-2
# 3   3     FGJ  FGJ-011        Coordinación Territorial Coy-3
# 4   4     FGJ  FGJ-012        Coordinación Territorial Coy-4
#
#                                        calle numero_exterior numero_interior  \
# 0           Av de las Culturas y eje 5 Norte             S/N             S/N
# 1  Avenida Cuauhtémoc esquina Obrero Mundial             S/N             S/N
# 2               Zompantitla Esq. Tecualiapan             S/N             S/N
# 3                     Apaches Esq. Eje 3 Ote             S/N             S/N
# 4              Rey Tepalcanzin y Chichimecas             S/N             S/N
#
#                    colonia       alcaldia  codigo_postal  ...  \
# 0   San Martin Xochinahuac   Azcapotzalco         2120.0  ...
# ...

# %%
cdmx
# Out:
#       id id_ente  id_sede                                  nombre_de_la_sede  \
# 0      0     FGJ  FGJ-005               Coordinacion Territorial Az-1 y Az-3
# 1      1     FGJ  FGJ-007               Coordinación Territorial BJ-3 y Bj-4
# 2      2     FGJ  FGJ-010                     Coordinación Territorial Coy-2
# 3      3     FGJ  FGJ-011                     Coordinación Territorial Coy-3
# 4      4     FGJ  FGJ-012                     Coordinación Territorial Coy-4
# ..   ...     ...      ...                                                ...
# 318  318     IZP  IZP-007                       Ventanilla Única de Trámites
# 319  319     MAC  MAC-003                  Consultorio Psicológico La Lupita
# 320  320     MAC  MAC-007                Coordinación de Seguridad Ciudadana
# 321  321     MIL  MIL-002  Subdirección de Igualdad Sustantiva y Derechos...
# 322  322     MIL  MIL-006  Jefatura de la Unidad Departamental de Atenció...
#
# ...

# %%
cdmx.columns
# Out:
# Index(['id', 'id_ente', 'id_sede', 'nombre_de_la_sede', 'calle',
#        'numero_exterior', 'numero_interior', 'colonia', 'alcaldia',
#        'codigo_postal', 'referencias_de_ubicacion', 'horario_de_atencion',
#        'dias_de_atencion', 'correo_electronico', 'tel_1', 'ext_1', 'tel_2',
#        'ext_2', 'intervencion_en_crisis', 'terapia_individual',
#        'terapia_grupal', 'impresion_diagnostica', 'psiquiatrica',
#        'salud_reproductiva', 'atencion_por_lesiones', 'ile', 'ive',
#        'casa_de_emergencia', 'refugio', 'orientacion_o_asesoria_juridica',
#        'acompanamiento_juridico', 'representacion_juridica',
#        'medidas_de_proteccion', 'apertura_de_carpeta_de_investigacion',
#        'informacion_y_orientacion', 'perfiles_socioeconomicos',
#        'visitas_de_seguimiento',
#        'atencion_re_educativa_a_hombres_que_ejercen_violencia',
#        'atencion_psicoterapeutica_a_personas_generadoras_de_violencia',
# ...

# %%
cdmx.pivot_table(index="alcaldia", columns='apertura_de_carpeta_de_investigacion', values='atencion_psicoterapeutica_a_personas_generadoras_de_violencia', aggfunc='count')
# Out:
# apertura_de_carpeta_de_investigacion  No  Sí
# alcaldia
# Azcapotzalco                           5   3
# Benito Juárez                         11   0
# Coyoacán                              10   0
# Cuajimalpa                             5   0
# Cuauhtémoc                            41  14
# Gustavo A. Madero                     17   1
# Iztacalco                             10   0
# Iztapalapa                            23   4
# Magdalena Contreras                   10   0
# Miguel Hidalgo                         9   0
# Milpa Alta                            14   0
# Tlalpan                                7   1
# Tláhuac                                6   0
# Venustiano Carranza                   10   1
# Xochimilco                             7   0
# Álvaro Obregón                         9   1

# %%
cdmx.pivot_table

# %%
cdmx.pivot_table.to_excel('pivot.xlsx', index=False)
